# %% [markdown]
# ### 4.Exploratory Data Analysis (Descriptive Data analysis + Inferential data ANalysis)

# %% [markdown]
# ##### 4.1. Univariate Analysis
# ##### 4.2. Bivariate Analysis
# ##### 4.3. Mutlivariate Analysis

# %% [markdown]
# ##### 4.1. Univariate Analysis(continuous and Discreate)
#             4.1.1. if continuous:
#                 4.1.1.1. Measure of central tendency (Mean,Median,Mode)
#                 4.1.1.2. Measure of location of the data (Frequency,cumulative frequency,Percentile,InterQuantile percentile,Range)
#                 4.1.1.3. Histogram and skewness
#                 4.1.1.4. Measure of Spread (Variance,Standard deviation,z-score)
#
#             4.1.2. if Discreate
#                 4.1.2.1. Frequency Analysis (Bar chart,pie chart,Graps)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
dataset=pd.read_csv("data/climate_change_impact_on_agriculture_2024.csv")

# %%
df=dataset

# %%
df.head()
# Out:
#    Year Country         Region  Crop_Type  Average_Temperature_C  \
# 0  2001   India    West Bengal       Corn                   1.55
# 1  2024   China          North       Corn                   3.23
# 2  2001  France  Ile-de-France      Wheat                  21.11
# 3  2001  Canada       Prairies     Coffee                  27.85
# 4  1998   India     Tamil Nadu  Sugarcane                   2.19
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                  447.06             15.22                 1.737
# 1                 2913.57             29.82                 1.737
# 2                 1301.74             25.75                 1.719
# 3                 1154.36             13.91                 3.890
# 4                 1627.48             11.81                 1.080
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                14.54                    10.08
# ...

# %% [markdown]
# # Separate Quan and Qual

# %%
df.columns
# Out:
# Index(['Year', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C',
#        'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA',
#        'Extreme_Weather_Events', 'Irrigation_Access_%',
#        'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA',
#        'Soil_Health_Index', 'Adaptation_Strategies',
#        'Economic_Impact_Million_USD'],
#       dtype='object')

# %%
def QuanQual(df):
    Quan = [feature for feature in df.columns if df[feature].dtype != 'O']
    Qual = [feature for feature in df.columns if df[feature].dtype == 'O']
    return Quan,Qual

# %%
Quan,Qual= QuanQual(df)

# %%
Quan
# Out:
# ['Year',
#  'Average_Temperature_C',
#  'Total_Precipitation_mm',
#  'CO2_Emissions_MT',
#  'Crop_Yield_MT_per_HA',
#  'Extreme_Weather_Events',
#  'Irrigation_Access_%',
#  'Pesticide_Use_KG_per_HA',
#  'Fertilizer_Use_KG_per_HA',
#  'Soil_Health_Index',
#  'Economic_Impact_Million_USD']

# %%
Qual
# Out:
# ['Country', 'Region', 'Crop_Type', 'Adaptation_Strategies']

# %% [markdown]
# ### 4.1.1.1 Measure of central tendency (1.Mean, 2.Median,3.Mode)
# ### 4.1.1,2. Measure of location of the data (3.Percentile and 4.InterQuantile percentile)
# ### 4.1.1.3. Histogram and skewness,kurtosis
# ### 4.1.1.4. Measure of Spread (Variance,Standard deviation)

# %%
from UnivariateAnalysis import Univariate
import numpy as np
result = Univariate.descriptive(df,Quan)
result
# Out:
#                        Year Average_Temperature_C Total_Precipitation_mm  \
# Mean              2007.0887             15.241299            1611.663834
# Median               2007.0                15.175                1611.16
# Mode                   1999                  3.41                1377.47
# Q1:25%               1999.0                  5.43               925.6975
# Q2:50%               2007.0                15.175                1611.16
# Q3:75%               2016.0                 25.34              2306.9975
# 99%                  2024.0                 34.62              2975.9511
# Q4:100%              2024.0                  35.0                2999.67
# IQR                    17.0                 19.91                 1381.3
# 1.5_Rule               25.5                29.865                2071.95
# Lesser_outlier       1973.5               -24.435             -1146.2525
# Greater_outlier      2041.5                55.205              4378.9475
# ...

# %% [markdown]
# ### 4.1.1.2. Measure of location of the data (1.Frequency,2.Cumulative Frequency)
# ### "Unique_values","Frequency","Relative_Frequency","Cumsum"

# %%
from UnivariateAnalysis import Univariate
#import pandas as pd
#import numpy as np
result = Univariate.FreqTable("Average_Temperature_C",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0              3.41          9            0.087379   0.087379
# 1             33.19          9            0.087379   0.174757
# 2             20.35          9            0.087379   0.262136
# 3             18.13          8            0.077670   0.339806
# 4              0.15          8            0.077670   0.417476
# ...             ...        ...                 ...        ...
# 3672          12.63          1            0.009709  97.048544
# 3673          17.48          1            0.009709  97.058252
# 3674           3.03          1            0.009709  97.067961
# 3675           1.28          1            0.009709  97.077670
# 3676           9.53          1            0.009709  97.087379
#
# [3677 rows x 4 columns]

# %%
result = Univariate.FreqTable("Total_Precipitation_mm",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0           1377.47          3            0.029126   0.029126
# 1           2624.98          2            0.019417   0.048544
# 2           2642.21          2            0.019417   0.067961
# 3           2855.34          2            0.019417   0.087379
# 4            679.97          2            0.019417   0.106796
# ...             ...        ...                 ...        ...
# 9779        2373.23          1            0.009709  97.048544
# 9780        1841.78          1            0.009709  97.058252
# 9781        2388.71          1            0.009709  97.067961
# 9782        1061.11          1            0.009709  97.077670
# 9783        1676.25          1            0.009709  97.087379
#
# [9784 rows x 4 columns]

# %%
result = Univariate.FreqTable("CO2_Emissions_MT",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0             25.23         11            0.106796   0.106796
# 1              5.34         10            0.097087   0.203883
# 2             27.77         10            0.097087   0.300971
# 3             17.71         10            0.097087   0.398058
# 4             19.85         10            0.097087   0.495146
# ...             ...        ...                 ...        ...
# 2847          21.61          1            0.009709  97.048544
# 2848           1.26          1            0.009709  97.058252
# 2849           5.40          1            0.009709  97.067961
# 2850          14.76          1            0.009709  97.077670
# 2851          17.64          1            0.009709  97.087379
#
# [2852 rows x 4 columns]

# %%
result = Univariate.FreqTable("Crop_Yield_MT_per_HA",df)
result
# Out:
#      Unique_values  Frequency  Relative_Frequency     Cumsum
# 0            1.530         44            0.427184   0.427184
# 1            2.160         39            0.378641   0.805825
# 2            1.800         37            0.359223   1.165049
# 3            2.520         36            0.349515   1.514563
# 4            0.900         36            0.349515   1.864078
# ..             ...        ...                 ...        ...
# 845          4.170          1            0.009709  97.048544
# 846          4.520          1            0.009709  97.058252
# 847          4.090          1            0.009709  97.067961
# 848          3.645          1            0.009709  97.077670
# 849          4.194          1            0.009709  97.087379
#
# [850 rows x 4 columns]

# %%
result = Univariate.FreqTable("Extreme_Weather_Events",df)
result
# Out:
#     Unique_values  Frequency  Relative_Frequency     Cumsum
# 0               1        957            9.291262   9.291262
# 1               6        929            9.019417  18.310680
# 2               9        917            8.902913  27.213592
# 3               3        915            8.883495  36.097087
# 4               5        914            8.873786  44.970874
# 5              10        908            8.815534  53.786408
# 6               2        899            8.728155  62.514563
# 7               0        899            8.728155  71.242718
# 8               4        895            8.689320  79.932039
# 9               7        884            8.582524  88.514563
# 10              8        883            8.572816  97.087379

# %%
result = Univariate.FreqTable("Irrigation_Access_%",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0             79.29          7            0.067961   0.067961
# 1             74.86          6            0.058252   0.126214
# 2             19.24          6            0.058252   0.184466
# 3             98.54          6            0.058252   0.242718
# 4             80.44          6            0.058252   0.300971
# ...             ...        ...                 ...        ...
# 5998          55.04          1            0.009709  97.048544
# 5999          45.20          1            0.009709  97.058252
# 6000          49.31          1            0.009709  97.067961
# 6001          22.32          1            0.009709  97.077670
# 6002          78.53          1            0.009709  97.087379
#
# [6003 rows x 4 columns]

# %%
result = Univariate.FreqTable("Pesticide_Use_KG_per_HA",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0             37.76          8            0.077670   0.077670
# 1             44.69          8            0.077670   0.155340
# 2              0.72          8            0.077670   0.233010
# 3              2.78          8            0.077670   0.310680
# 4              5.82          8            0.077670   0.388350
# ...             ...        ...                 ...        ...
# 4338          40.52          1            0.009709  97.048544
# 4339           4.81          1            0.009709  97.058252
# 4340          33.34          1            0.009709  97.067961
# 4341          40.88          1            0.009709  97.077670
# 4342          44.54          1            0.009709  97.087379
#
# [4343 rows x 4 columns]

# %%
result = Univariate.FreqTable("Fertilizer_Use_KG_per_HA",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0              6.07          6            0.058252   0.058252
# 1             77.99          6            0.058252   0.116505
# 2             93.14          6            0.058252   0.174757
# 3             65.33          6            0.058252   0.233010
# 4             72.31          6            0.058252   0.291262
# ...             ...        ...                 ...        ...
# 6309          37.10          1            0.009709  97.048544
# 6310          97.89          1            0.009709  97.058252
# 6311          64.48          1            0.009709  97.067961
# 6312          68.91          1            0.009709  97.077670
# 6313          10.95          1            0.009709  97.087379
#
# [6314 rows x 4 columns]

# %%
result = Univariate.FreqTable("Soil_Health_Index",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0             79.38          8            0.077670   0.077670
# 1             63.03          7            0.067961   0.145631
# 2             64.29          6            0.058252   0.203883
# 3             63.62          6            0.058252   0.262136
# 4             31.44          6            0.058252   0.320388
# ...             ...        ...                 ...        ...
# 5313          30.34          1            0.009709  97.048544
# 5314          97.90          1            0.009709  97.058252
# 5315          36.80          1            0.009709  97.067961
# 5316          65.53          1            0.009709  97.077670
# 5317          59.38          1            0.009709  97.087379
#
# [5318 rows x 4 columns]

# %%
result = Univariate.FreqTable("Economic_Impact_Million_USD",df)
result
# Out:
#       Unique_values  Frequency  Relative_Frequency     Cumsum
# 0            616.60          4            0.038835   0.038835
# 1           1012.69          3            0.029126   0.067961
# 2            447.71          3            0.029126   0.097087
# 3            227.76          3            0.029126   0.126214
# 4            643.72          3            0.029126   0.155340
# ...             ...        ...                 ...        ...
# 9626         447.74          1            0.009709  97.048544
# 9627         180.21          1            0.009709  97.058252
# 9628         649.78          1            0.009709  97.067961
# 9629         482.38          1            0.009709  97.077670
# 9630         453.14          1            0.009709  97.087379
#
# [9631 rows x 4 columns]

# %% [markdown]
# ## PDF and CDF

# %%
import seaborn as sns

# %%
sns.distplot(df["Average_Temperature_C"])
# Out:
# <Axes: xlabel='Average_Temperature_C', ylabel='Density'>

# %%
def get_pdf_probability(df,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax=sns.distplot(df,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')

    #generate a sample
    sample=df

    # calculate parameter
    sample_mean=sample.mean()
    sample_std=sample.std()
    print("Mean=%.3f,Standard Deviation=%.3f" % (sample_mean,sample_std))

    #define the distribution
    dist=norm(sample_mean,sample_std)

    #sample probabilities for a range of outcomes
    values=[ value for value in range(startrange,endrange)]
    Probabilities=[dist.pdf(value) for value in values]
    prob=sum(Probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(Probabilities)))

    return prob

# %%
get_pdf_probability(df["Average_Temperature_C"],20,40)
# Out:
# Mean=15.241,Standard Deviation=11.467
# The area between range(20,40):0.33796623327028685
# 0.33796623327028685

# %% [markdown]
# ### cumulative density function

# %%
#!pip install statsmodels

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf=ECDF(df['CO2_Emissions_MT'])
ecdf(46)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 from statsmodels.distributions.empirical_distribution import ECDF
# ----> 2 ecdf=ECDF(df['CO2_Emissions_MT'])
#       3 ecdf(46)
#
# NameError: name 'df' is not defined

# %%
ecdf(51)
# Out:
# 1.0

# %%
ecdf(76)
# Out:
# 1.0

# %% [markdown]
# # Bivariate Anaysis
#         1. Co-variance and Corr
#         2. Multicolinearity- VIF
#         3. T-Test
#         4. Hypothesis Testing
#         5. Anavo

# %%
df2=df[Quan]

# %%
df2
# Out:
#       Year  Average_Temperature_C  Total_Precipitation_mm  CO2_Emissions_MT  \
# 0     2001                   1.55                  447.06             15.22
# 1     2024                   3.23                 2913.57             29.82
# 2     2001                  21.11                 1301.74             25.75
# 3     2001                  27.85                 1154.36             13.91
# 4     1998                   2.19                 1627.48             11.81
# ...    ...                    ...                     ...               ...
# 9995  2022                  30.48                  685.93             17.64
# 9996  1999                   9.53                 2560.38             10.68
# 9997  2000                  31.92                  357.76             26.01
# 9998  1996                  13.95                 1549.52             17.31
# 9999  2015                  11.78                 1676.25              5.34
#
# ...

# %% [markdown]
# ### Co-Variance

# %%
df2.cov()
# Out:
#                                    Year  Average_Temperature_C  \
# Year                         101.692002              -0.529990
# Average_Temperature_C         -0.529990             131.491048
# Total_Precipitation_mm        53.179069              66.583786
# CO2_Emissions_MT              -0.472998              -0.300631
# Crop_Yield_MT_per_HA           0.108068               3.019745
# Extreme_Weather_Events        -0.087015              -0.610180
# Irrigation_Access_%            0.245891              -3.954098
# Pesticide_Use_KG_per_HA       -0.633055               0.957756
# Fertilizer_Use_KG_per_HA       3.802193              -4.847970
# Soil_Health_Index             -1.281911              -2.510625
# Economic_Impact_Million_USD   51.922053             930.982207
#
#                              Total_Precipitation_mm  CO2_Emissions_MT  \
# Year                                      53.179069         -0.472998
# ...

# %% [markdown]
# ### Correlation

# %%
df2.corr()
# Out:
#                                  Year  Average_Temperature_C  \
# Year                         1.000000              -0.004583
# Average_Temperature_C       -0.004583               1.000000
# Total_Precipitation_mm       0.006551               0.007213
# CO2_Emissions_MT            -0.005461              -0.003052
# Crop_Yield_MT_per_HA         0.010734               0.263781
# Extreme_Weather_Events      -0.002726              -0.016808
# Irrigation_Access_%          0.000938              -0.013268
# Pesticide_Use_KG_per_HA     -0.004332               0.005764
# Fertilizer_Use_KG_per_HA     0.013132              -0.014725
# Soil_Health_Index           -0.006294              -0.010841
# Economic_Impact_Million_USD  0.012419               0.195827
#
#                              Total_Precipitation_mm  CO2_Emissions_MT  \
# Year                                       0.006551         -0.005461
# Average_Temperature_C                      0.007213         -0.003052
# ...

# %% [markdown]
# #### VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):
    #calculating VIF
    vif=pd.DataFrame()
    vif["variable"]=X.columns
    vif["VIF"]= [variance_inflation_factor(X.values ,i) for i in range(X.shape[1])]
    return vif

# %%
calc_vif(df2[Quan])
# Out:
#                        variable        VIF
# 0                          Year  37.920361
# 1         Average_Temperature_C   2.977532
# 2        Total_Precipitation_mm   5.020176
# 3              CO2_Emissions_MT   4.189473
# 4          Crop_Yield_MT_per_HA  13.281384
# 5        Extreme_Weather_Events   3.478943
# 6           Irrigation_Access_%   5.522222
# 7       Pesticide_Use_KG_per_HA   3.969458
# 8      Fertilizer_Use_KG_per_HA   4.038610
# 9             Soil_Health_Index  11.335026
# 10  Economic_Impact_Million_USD   7.719410

# %%
# drop year . bcoz its have highly multilicolinearity

# %%
calc_vif(df2[['Average_Temperature_C','Total_Precipitation_mm','CO2_Emissions_MT','Crop_Yield_MT_per_HA','Extreme_Weather_Events','Irrigation_Access_%','Pesticide_Use_KG_per_HA','Fertilizer_Use_KG_per_HA','Soil_Health_Index','Economic_Impact_Million_USD']])
# Out:
#                       variable        VIF
# 0        Average_Temperature_C   2.924038
# 1       Total_Precipitation_mm   4.461174
# 2             CO2_Emissions_MT   3.761857
# 3         Crop_Yield_MT_per_HA  12.493338
# 4       Extreme_Weather_Events   3.268639
# 5          Irrigation_Access_%   4.848286
# 6      Pesticide_Use_KG_per_HA   3.683994
# 7     Fertilizer_Use_KG_per_HA   3.686226
# 8            Soil_Health_Index   8.240041
# 9  Economic_Impact_Million_USD   7.718539

# %%
calc_vif(df2[['Average_Temperature_C','CO2_Emissions_MT','Extreme_Weather_Events','Pesticide_Use_KG_per_HA','Fertilizer_Use_KG_per_HA','Economic_Impact_Million_USD']])
# Out:
#                       variable       VIF
# 0        Average_Temperature_C  2.686439
# 1             CO2_Emissions_MT  3.296386
# 2       Extreme_Weather_Events  2.977359
# 3      Pesticide_Use_KG_per_HA  3.274996
# 4     Fertilizer_Use_KG_per_HA  3.270071
# 5  Economic_Impact_Million_USD  3.298473

# %% [markdown]
# ## T-Test

# %% [markdown]
# #### independent sample - unpaired T-Test

# %% [markdown]
# #### Dependent sample -paired T-Test

# %%
df.Country.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df.Country.unique()
#
# NameError: name 'df' is not defined

# %%
df[df["Country"]=='India']["Economic_Impact_Million_USD"]
# Out:
# 0        808.13
# 4        401.72
# 8        761.89
# 21      1745.39
# 51       308.77
#          ...
# 9930     490.45
# 9939     611.19
# 9957     162.75
# 9959     557.36
# 9985    1852.07
# Name: Economic_Impact_Million_USD, Length: 1025, dtype: float64

# %%
df[df["Country"]=='China']["Economic_Impact_Million_USD"]
# Out:
# 1        616.22
# 34       776.00
# 35       140.36
# 47       118.24
# 50       600.91
#          ...
# 9989     284.34
# 9990     981.05
# 9991     181.28
# 9994    1047.69
# 9999     453.14
# Name: Economic_Impact_Million_USD, Length: 1031, dtype: float64

# %%
df[df["Country"]=='Canada']["Economic_Impact_Million_USD"]
# Out:
# 3        790.32
# 26       432.78
# 30       829.00
# 31       928.74
# 32       251.00
#          ...
# 9928     246.84
# 9937    1451.06
# 9954     243.07
# 9958     650.84
# 9988    1000.74
# Name: Economic_Impact_Million_USD, Length: 984, dtype: float64

# %%
df[df["Country"]=='USA']["Economic_Impact_Million_USD"]
# Out:
# 5        353.16
# 13      1126.27
# 25      1492.19
# 45       925.79
# 60       509.77
#          ...
# 9929    1100.84
# 9947     774.78
# 9964    1744.66
# 9982    1291.31
# 9983     592.90
# Name: Economic_Impact_Million_USD, Length: 1032, dtype: float64

# %%
df[df["Country"]=='Argentina']["Economic_Impact_Million_USD"]
# Out:
# 6        480.61
# 22       384.91
# 28      1100.96
# 39       687.85
# 43       524.89
#          ...
# 9973    1029.27
# 9975     166.70
# 9978     222.85
# 9979     362.99
# 9997     155.99
# Name: Economic_Impact_Million_USD, Length: 984, dtype: float64

# %%
df[df["Country"]=='Australia']["Economic_Impact_Million_USD"]
# Out:
# 7       1367.97
# 20       345.85
# 23      1222.94
# 29      1244.49
# 40       440.49
#          ...
# 9936     784.11
# 9942     148.94
# 9963     887.16
# 9965     608.80
# 9996     829.61
# Name: Economic_Impact_Million_USD, Length: 1032, dtype: float64

# %%
df[df["Country"]=='Nigeria']["Economic_Impact_Million_USD"]
# Out:
# 9        167.21
# 10      1100.44
# 14       894.31
# 17       571.98
# 69       966.48
#          ...
# 9877     265.29
# 9881    1312.51
# 9888     362.80
# 9896    1368.26
# 9969     868.93
# Name: Economic_Impact_Million_USD, Length: 1029, dtype: float64

# %%
df[df["Country"]=='Russia']["Economic_Impact_Million_USD"]
# Out:
# 12      1201.80
# 19      1805.57
# 41      1018.44
# 42      1438.48
# 73       657.55
#          ...
# 9967     200.40
# 9968     816.86
# 9970     297.63
# 9972    1164.44
# 9984     377.08
# Name: Economic_Impact_Million_USD, Length: 961, dtype: float64

# %%
df[df["Country"]=='Brazil']["Economic_Impact_Million_USD"]
# Out:
# 16       521.59
# 18      1323.81
# 27       933.72
# 36      1581.37
# 37       205.93
#          ...
# 9950     343.29
# 9960     415.97
# 9980     858.14
# 9981     510.45
# 9998    1613.90
# Name: Economic_Impact_Million_USD, Length: 944, dtype: float64

# %%
df[df["Country"]=='France']["Economic_Impact_Million_USD"]
# Out:
# 2        796.96
# 11       820.55
# 15      1524.34
# 24       317.95
# 57       748.93
#          ...
# 9961     658.32
# 9962     744.46
# 9992     227.30
# 9993     523.60
# 9995    1483.06
# Name: Economic_Impact_Million_USD, Length: 978, dtype: float64

# %% [markdown]
# # independent sample - unpaired T-Test

# %% [markdown]
# Different Group(India', 'China', 'France', 'Canada', 'USA', 'Argentina',
#        'Australia', 'Nigeria', 'Russia', 'Brazil') but same conditions (Economic_Impact_Million_USD)

# %%
from scipy.stats import ttest_ind
df=df.dropna()
India=df[df["Country"]=='India']["Economic_Impact_Million_USD"]
China=df[df["Country"]=='China']["Economic_Impact_Million_USD"]
France=df[df["Country"]=='France']["Economic_Impact_Million_USD"]
Canada=df[df["Country"]=='Canada']["Economic_Impact_Million_USD"]
USA=df[df["Country"]=='USA']["Economic_Impact_Million_USD"]
Argentina=df[df["Country"]=='Argentina']["Economic_Impact_Million_USD"]
Australia=df[df["Country"]=='Australia']["Economic_Impact_Million_USD"]
Nigeria=df[df["Country"]=='Nigeria']["Economic_Impact_Million_USD"]
Russia=df[df["Country"]=='Russia']["Economic_Impact_Million_USD"]
Brazil=df[df["Country"]=='Brazil']["Economic_Impact_Million_USD"]

print (India)
# Out:
# 0        808.13
# 4        401.72
# 8        761.89
# 21      1745.39
# 51       308.77
#          ...
# 9930     490.45
# 9939     611.19
# 9957     162.75
# 9959     557.36
# 9985    1852.07
# Name: Economic_Impact_Million_USD, Length: 1025, dtype: float64

# %%
ttest_ind(India,China)
# Out:
# TtestResult(statistic=0.47319891712531076, pvalue=0.6361215531840723, df=2054.0)

# %%
ttest_ind(France,Canada)
# Out:
# TtestResult(statistic=-0.9185383058109333, pvalue=0.3584501333967396, df=1960.0)

# %%
ttest_ind(USA,Argentina)
# Out:
# TtestResult(statistic=-0.4946019374101148, pvalue=0.620935080794138, df=2014.0)

# %%
ttest_ind(Australia,Nigeria)
# Out:
# TtestResult(statistic=-2.053681744210009, pvalue=0.04013254646808029, df=2059.0)

# %%
ttest_ind(Russia,Brazil)
# Out:
# TtestResult(statistic=-0.4736327713143277, pvalue=0.635816131203216, df=1903.0)

# %% [markdown]
# # Dependent sample -paired T-Test

# %% [markdown]
# Same Group(India) but different conditions (Pesticide_Use_KG_per_HA and Fertilizer_Use_KG_per_HA)

# %%
from scipy.stats import ttest_rel
India1= df[df["Country"]=="India"]["Pesticide_Use_KG_per_HA"]
India2= df[df["Country"]=="India"]["Fertilizer_Use_KG_per_HA"]
ttest_rel(India1,India2)
# Out:
# TtestResult(statistic=-23.377065113734808, pvalue=3.381348263955263e-97, df=1024)

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# Statement : Test whether Pesticide_Use_KG_per_HA of USA and Fertilizer_Use_KG_per_HA of USA is same?

# %% [markdown]
# Null hypothesis : There is no similarity between Pesticide_Use_KG_per_HA of India and Fertilizer_Use_KG_per_HA of India.

# %%
from scipy.stats import ttest_rel
India1= df[df["Country"]=="India"]["Pesticide_Use_KG_per_HA"]
India2= df[df["Country"]=="India"]["Fertilizer_Use_KG_per_HA"]
ttest_rel(India1,India2)
# Out:
# TtestResult(statistic=-23.377065113734808, pvalue=3.381348263955263e-97, df=1024)

# %%
# Reject null hypothesis when the p value is <0.05 .Here p value is > 0.05 .so that, reject alternate hypothesis and accept null hypothesis.

# %% [markdown]
# ### ANOVA(Analysis of variance)

# %%
import scipy.stats as stats
stats.f_oneway(df["Average_Temperature_C"],df["Pesticide_Use_KG_per_HA"],df["Fertilizer_Use_KG_per_HA"])
# Out:
# F_onewayResult(statistic=8263.021100959579, pvalue=0.0)

# %% [markdown]
# Reject null hypothesis when the p value is <0.05 .Reject alternate hypothersis when p value is > 0.05 .so that, accept alternate hypothesis and reject null hypothesis.
